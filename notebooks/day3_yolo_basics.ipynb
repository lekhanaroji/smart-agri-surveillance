# %%
from ultralytics import YOLO

# Load pre-trained model
model = YOLO("yolov8n.pt")

print("YOLO model loaded successfully!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 294.9KB/s 21.7s.6s<0.2ss4.4s
# YOLO model loaded successfully!

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO("yolov8n.pt")

# Detect objects in the image
results = model("test.jpg")

print("Detection completed!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       3 # Load YOLO model
#       4 model = YOLO("yolov8n.pt")
#       5
#       6 # Detect objects in the image
# ----> 7 results = model("test.jpg")
#       8
#       9 print("Detection completed!")
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\model.py:537, in Model.predict(self, source, stream, predictor, **kwargs)
#     535 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     536     self.predictor.set_prompts(prompts)
# --> 537 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     226     return self.stream_inference(source, model, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:302, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     298     self.setup_model(model)
#     300 with self._lock:  # for thread-safe inference
#     301     # Setup source every time predict is called
# --> 302     self.setup_source(source if source is not None else self.args.source)
#     304     # Check if save_dir/ label file exists
#     305     if self.args.save or self.args.save_txt:
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.setup_source(self, source, stride)
#     251 """Set up source and inference mode.
#     252
#     253 Args:
#    (...)    256     stride (int, optional): Model stride for image size checking.
#     257 """
#     258 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 259 self.dataset = load_inference_source(
#     260     source=source,
#     261     batch=self.args.batch,
#     262     vid_stride=self.args.vid_stride,
#     263     buffer=self.args.stream_buffer,
#     264     channels=getattr(self.model, "channels", 3),
#     265 )
#     266 self.source_type = self.dataset.source_type
#     267 if (
#     268     self.source_type.stream
#     269     or self.source_type.screenshot
#     270     or len(self.dataset) > 1000  # many images
#     271     or any(getattr(self.dataset, "video_flag", [False]))
#     272 ):  # long sequence
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\data\build.py:461, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     459     dataset = LoadPilAndNumpy(source, channels=channels)
#     460 else:
# --> 461     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     463 # Attach source types to the dataset
#     464 setattr(dataset, "source_type", source_type)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\data\loaders.py:374, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     372         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     373     else:
# --> 374         raise FileNotFoundError(f"{p} does not exist")
#     376 # Define files as images or videos
#     377 images, videos = [], []
#
# FileNotFoundError: test.jpg does not exist

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\RAMESHJOSHI\smart_agri_surveillance\notebooks

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model("test.jpg", show=True)

print("Detection completed!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8n.pt")
#       4
# ----> 5 results = model("test.jpg", show=True)
#       6
#       7 print("Detection completed!")
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\model.py:537, in Model.predict(self, source, stream, predictor, **kwargs)
#     535 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     536     self.predictor.set_prompts(prompts)
# --> 537 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     226     return self.stream_inference(source, model, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:302, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     298     self.setup_model(model)
#     300 with self._lock:  # for thread-safe inference
#     301     # Setup source every time predict is called
# --> 302     self.setup_source(source if source is not None else self.args.source)
#     304     # Check if save_dir/ label file exists
#     305     if self.args.save or self.args.save_txt:
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.setup_source(self, source, stride)
#     251 """Set up source and inference mode.
#     252
#     253 Args:
#    (...)    256     stride (int, optional): Model stride for image size checking.
#     257 """
#     258 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 259 self.dataset = load_inference_source(
#     260     source=source,
#     261     batch=self.args.batch,
#     262     vid_stride=self.args.vid_stride,
#     263     buffer=self.args.stream_buffer,
#     264     channels=getattr(self.model, "channels", 3),
#     265 )
#     266 self.source_type = self.dataset.source_type
#     267 if (
#     268     self.source_type.stream
#     269     or self.source_type.screenshot
#     270     or len(self.dataset) > 1000  # many images
#     271     or any(getattr(self.dataset, "video_flag", [False]))
#     272 ):  # long sequence
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\data\build.py:461, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     459     dataset = LoadPilAndNumpy(source, channels=channels)
#     460 else:
# --> 461     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     463 # Attach source types to the dataset
#     464 setattr(dataset, "source_type", source_type)
#
# File ~\smart_agri_surveillance\venv\Lib\site-packages\ultralytics\data\loaders.py:374, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     372         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     373     else:
# --> 374         raise FileNotFoundError(f"{p} does not exist")
#     376 # Define files as images or videos
#     377 images, videos = [], []
#
# FileNotFoundError: test.jpg does not exist

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\RAMESHJOSHI\smart_agri_surveillance\notebooks

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'day1_environment_test.ipynb', 'pic 1.jpg', 'yolov8n.pt', 'yolo_basics.ipynb']

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model("pic 1.jpg", show=True)

print("Detection completed!")
# Out:
# image 1/1 C:\Users\RAMESHJOSHI\smart_agri_surveillance\notebooks\pic 1.jpg: 576x640 1 car, 8428.8ms
# Speed: 2074.5ms preprocess, 8428.8ms inference, 1590.0ms postprocess per image at shape (1, 3, 576, 640)
# Detection completed!

# %%
for result in results:
    boxes = result.boxes

    for box in boxes:
        class_id = int(box.cls)
        confidence = float(box.conf)

        class_name = model.names[class_id]

        print(
            f"Class: {class_name}, "
            f"Confidence: {confidence:.2f}"
        )
# Out:
# Class: car, Confidence: 0.25

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("YOLO Webcam Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1 giraffe, 1 tv, 1585.6ms
# Speed: 36.4ms preprocess, 1585.6ms inference, 20.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 959.7ms
# Speed: 9.7ms preprocess, 959.7ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 967.7ms
# Speed: 7.8ms preprocess, 967.7ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 956.6ms
# Speed: 7.0ms preprocess, 956.6ms inference, 23.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1002.1ms
# Speed: 5.3ms preprocess, 1002.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 950.9ms
# Speed: 5.0ms preprocess, 950.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1 laptop, 977.3ms
# Speed: 6.9ms preprocess, 977.3ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 991.3ms
# Speed: 7.9ms preprocess, 991.3ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1226.2ms
# Speed: 5.6ms preprocess, 1226.2ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 1600.2ms
# Speed: 12.7ms preprocess, 1600.2ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 946.1ms
# Speed: 63.8ms preprocess, 946.1ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
